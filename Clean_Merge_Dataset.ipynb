# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
# Import dataset 1
vgsales_df = pd.read_csv('Resources/Video-Game-Sales.csv')
vgsales_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
Total_Sales = vgsales_df['NA_Sales'] + vgsales_df['EU_Sales'] + vgsales_df['JP_Sales'] + vgsales_df['Other_Sales'] + vgsales_df['Global_Sales']

# %%
vgsales_df['Total_Sales'] = Total_Sales

# %%
vgsales_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vgsales_df.drop(['Rank', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'], axis=1, inplace=True)

# %%
# Import dataset 2
vgreviews_df = pd.read_csv('Resources/all_games.csv')
vgreviews_df
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date                                            summary  \
# 0       November 23, 1998  As a young boy, Link is tricked by Ganondorf, ...
# ...

# %%
# Rename columns to match other dataset
vgreviews_df = vgreviews_df.rename(columns={"name":"Name"})
vgreviews_df
# Out:
#                                              Name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date                                            summary  \
# 0       November 23, 1998  As a young boy, Link is tricked by Ganondorf, ...
# ...

# %%
vgreviews_df.drop(['platform', 'release_date', 'summary','user_review'], axis=1, inplace=True)

# %%
vgsales_df.isnull().sum()
# Out:
# Name           0
# Total_Sales    0
# dtype: int64

# %%
vgreviews_df.isnull().sum()
# Out:
# Name          0
# meta_score    0
# dtype: int64

# %%
vgsales_df.dtypes
# Out:
# Name            object
# Total_Sales    float64
# dtype: object

# %%
vgreviews_df.dtypes
# Out:
# Name          object
# meta_score     int64
# dtype: object

# %%
vg_df = pd.merge(vgsales_df, vgreviews_df, how='inner', on=['Name'])

# %%
vg_df
# Out:
#                     Name  Total_Sales  meta_score
# 0             Wii Sports       165.48          76
# 1         Mario Kart Wii        71.65          82
# 2      Wii Sports Resort        66.00          80
# 3                 Tetris        60.52          85
# 4                 Tetris        60.52          80
# ...                  ...          ...         ...
# 18602          Teslagrad         0.02          77
# 18603  PGA European Tour         0.02          58
# 18604    Planet Monsters         0.02          67
# 18605             Breach         0.02          57
# 18606   Mega Brain Boost         0.02          48
#
# [18607 rows x 3 columns]

# %%
vg_df.isnull().sum()
# Out:
# Name           0
# Total_Sales    0
# meta_score     0
# dtype: int64

# %%
print(f"Duplicate entries: {vg_df.duplicated().sum()}")
# Out:
# Duplicate entries: 2002

# %%
vg_df = vg_df.drop_duplicates(subset=['Name'])

# %%
print(f"Duplicate entries: {vg_df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
vg_df
# Out:
#                         Name  Total_Sales  meta_score
# 0                 Wii Sports       165.48          76
# 1             Mario Kart Wii        71.65          82
# 2          Wii Sports Resort        66.00          80
# 3                     Tetris        60.52          85
# 7      New Super Mario Bros.        60.02          89
# ...                      ...          ...         ...
# 18599              Teslagrad         0.02          81
# 18603      PGA European Tour         0.02          58
# 18604        Planet Monsters         0.02          67
# 18605                 Breach         0.02          57
# 18606       Mega Brain Boost         0.02          48
#
# [4616 rows x 3 columns]

# %%
vg_df.to_csv('Resources/Video_Games.csv', index=False)
