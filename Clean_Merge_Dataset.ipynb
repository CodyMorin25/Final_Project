# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
# Import dataset 1
vgsales_df = pd.read_csv('Resources/Video-Game-Sales.csv')
vgsales_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vgsales_df.drop(['Rank', 'Platform', 'Year', 'Genre', 'Publisher'], axis=1, inplace=True)

# %%
# Import dataset 2
vgreviews_df = pd.read_csv('Resources/all_games.csv')
vgreviews_df
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date                                            summary  \
# 0       November 23, 1998  As a young boy, Link is tricked by Ganondorf, ...
# ...

# %%
# Rename columns to match other dataset
vgreviews_df = vgreviews_df.rename(columns={"name":"Name"})
vgreviews_df
# Out:
#                                              Name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date                                            summary  \
# 0       November 23, 1998  As a young boy, Link is tricked by Ganondorf, ...
# ...

# %%
vgreviews_df.drop(['platform', 'release_date', 'summary'], axis=1, inplace=True)

# %%
vgsales_df.isnull().sum()
# Out:
# Name            0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
vgreviews_df.isnull().sum()
# Out:
# Name           0
# meta_score     0
# user_review    0
# dtype: int64

# %%
vgsales_df.dtypes
# Out:
# Name             object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
vgreviews_df.dtypes
# Out:
# Name           object
# meta_score      int64
# user_review    object
# dtype: object

# %%
vg_df = pd.merge(vgsales_df, vgreviews_df, how='inner', on=['Name'])

# %%
vg_df
# Out:
#                     Name  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0             Wii Sports     41.49     29.02      3.77         8.46
# 1         Mario Kart Wii     15.85     12.88      3.79         3.31
# 2      Wii Sports Resort     15.75     11.01      3.28         2.96
# 3                 Tetris     23.20      2.26      4.22         0.58
# 4                 Tetris     23.20      2.26      4.22         0.58
# ...                  ...       ...       ...       ...          ...
# 18602          Teslagrad      0.00      0.01      0.00         0.00
# 18603  PGA European Tour      0.01      0.00      0.00         0.00
# 18604    Planet Monsters      0.01      0.00      0.00         0.00
# 18605             Breach      0.01      0.00      0.00         0.00
# 18606   Mega Brain Boost      0.01      0.00      0.00         0.00
#
#        Global_Sales  meta_score user_review
# 0             82.74          76         8.1
# 1             35.82          82         8.4
# ...

# %%
vg_df.isnull().sum()
# Out:
# Name            0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# meta_score      0
# user_review     0
# dtype: int64

# %%
vg_df.to_csv('Resour')
